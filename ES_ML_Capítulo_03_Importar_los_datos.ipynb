# %% [markdown]
# <a href="https://colab.research.google.com/github/joanby/trading-algoritmico-ml/blob/main/ES_ML_Cap%C3%ADtulo_03_Importar_los_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="https://www.quantreo.com/wp-content/uploads/2021/10/Original-on-Transparent.png" align="left" hspace="10px" vspace="0px">
# <img alt="Colaboratory logo" height="45px" src="https://static-881c.kxcdn.com/wp-content/uploads/2016/03/frogamesLogoFull4.png" align="left" hspace="10px" vspace="0px"></p>
#
#  # Importar los datos
# La importación de los datos es lo más importante. En efecto, unos datos erróneos podrían permitirnos tomar decisiones equivocadas sobre las estrategias a utilizar y, por tanto, perder dinero. Vamos a ver la librería de finanzas que nos permitirá importar los precios de yahoo finance con extrema facilidad. Sin embargo, esta facilidad tiene un precio. A veces los datos de yahoo son de mala calidad en algunos activos.
#
# <br>
# <br>
#
#
# **Es imprescindible verificar las estrategias de trading creadas utilizando los datos de su broker a posteriori. <br>
# TODOS LOS NOMBRES DE LOS TELETIPOS SON LOS MISMOS QUE LOS DEL SITIO WEB DE YAHOO FINANCE**
#
# <br>
#
# ### Contenido
# * Librería de Yahoo Finance
# * Algunas otras formas
#
# </br>
#
#
#
# 💰 Únete a la comunidad de [Discord](https://discord.gg/wXjNPAc5BH)
#
# 📚 Puedes leer nuestro libro en [Amazon](https://www.amazon.com/gp/product/B09HG18CYL)
#
# 🖥️ El canal de [YouTube de Quantreo's](https://www.youtube.com/channel/UCp7jckfiEglNf_Gj62VR0pw) (en inglés) y el de [Frogames](https://www.youtube.com/channel/UCMUxXNYrVCv6-bQakhomvBg) en español

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %% [markdown]
# # Sección 1: La librería de Yahoo Finance

# %%
# Importar la librería yfinance 
import yfinance as yf

# %%
# Importar simple de datos
yf.download("GOOG")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High        Low       Close   Adj Close  \
# Date
# 2004-08-19    2.490664    2.591785   2.390042    2.499133    2.499133
# 2004-08-20    2.515820    2.716817   2.503118    2.697639    2.697639
# 2004-08-23    2.758411    2.826406   2.716070    2.724787    2.724787
# 2004-08-24    2.770615    2.779581   2.579581    2.611960    2.611960
# 2004-08-25    2.614201    2.689918   2.587302    2.640104    2.640104
# ...                ...         ...        ...         ...         ...
# 2022-09-22   99.449997  101.680000  99.410004  100.570000  100.570000
# 2022-09-23  100.059998  100.110001  98.010002   99.169998   99.169998
# 2022-09-26   98.610001  100.440002  98.379997   98.809998   98.809998
# 2022-09-27   99.910004  100.459999  97.339996   98.089996   98.089996
# 2022-09-28   98.019997  101.400002  97.800003  100.739998  100.739998
#
#                Volume
# Date
# ...

# %%
# Importación múltiple
ticker_list = ["GOOG", "EURUSD=X", "^GSPC"]
yf.download(ticker_list)
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Adj Close                              Close              \
#             EURUSD=X        GOOG        ^GSPC  EURUSD=X        GOOG
# Date
# 1950-01-03       NaN         NaN    16.660000       NaN         NaN
# 1950-01-04       NaN         NaN    16.850000       NaN         NaN
# 1950-01-05       NaN         NaN    16.930000       NaN         NaN
# 1950-01-06       NaN         NaN    16.980000       NaN         NaN
# 1950-01-09       NaN         NaN    17.080000       NaN         NaN
# ...              ...         ...          ...       ...         ...
# 2022-09-23  0.984155   99.169998  3693.229980  0.984155   99.169998
# 2022-09-26  0.968992   98.809998  3655.040039  0.968992   98.809998
# 2022-09-27  0.962371   98.089996  3647.290039  0.962371   98.089996
# 2022-09-28  0.959619  100.739998  3719.040039  0.959619  100.739998
# 2022-09-29  0.969274         NaN          NaN  0.969274         NaN
#
# ...

# %%
# Personalizar los rangos de datos
yf.download(ticker_list, start="2000-01-01", end="2010-01-01")
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Adj Close                             Close             \
#             EURUSD=X       GOOG        ^GSPC  EURUSD=X       GOOG
# Date
# 2000-01-03       NaN        NaN  1455.219971       NaN        NaN
# 2000-01-04       NaN        NaN  1399.420044       NaN        NaN
# 2000-01-05       NaN        NaN  1402.109985       NaN        NaN
# 2000-01-06       NaN        NaN  1403.449951       NaN        NaN
# 2000-01-07       NaN        NaN  1441.469971       NaN        NaN
# ...              ...        ...          ...       ...        ...
# 2009-12-28  1.437505  15.513601  1127.780029  1.437505  15.513601
# 2009-12-29  1.434309  15.427175  1126.199951  1.434309  15.427175
# 2009-12-30  1.434206  15.510114  1126.420044  1.434206  15.510114
# 2009-12-31  1.432706  15.441621  1115.099976  1.432706  15.441621
# 2010-01-01  1.438994        NaN          NaN  1.438994        NaN
#
# ...

# %%
# Personalizar el intervalo de datos
yf.download(ticker_list, start="2000-01-01", end="2010-01-01", interval="1mo")
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Adj Close                             Close             \
#             EURUSD=X       GOOG        ^GSPC  EURUSD=X       GOOG
# Date
# 2000-01-01       NaN        NaN  1394.459961       NaN        NaN
# 2000-02-01       NaN        NaN  1366.420044       NaN        NaN
# 2000-03-01       NaN        NaN  1498.579956       NaN        NaN
# 2000-04-01       NaN        NaN  1452.430054       NaN        NaN
# 2000-05-01       NaN        NaN  1420.599976       NaN        NaN
# ...              ...        ...          ...       ...        ...
# 2009-09-01  1.465502  12.349959  1057.079956  1.465502  12.349959
# 2009-10-01  1.473297  13.352950  1036.189941  1.473297  13.352950
# 2009-11-01  1.503895  14.520573  1095.630005  1.503895  14.520573
# 2009-12-01  1.432706  15.441621  1115.099976  1.432706  15.441621
# 2010-01-01  1.387694        NaN          NaN  1.387694        NaN
#
# ...

# %% [markdown]
# # Algunos otros apuntes
# * **Puntos Fuertes**
# > * Utilización muy sencilla
# > * Muy fácil de encontrar el símbolo propuesto yendo al sitio web de Yahoo Finanzas
# > * Hay muchos datos. Muy útil para crear una cartera
#
# * **Puntos Débiles**
# > * Hay muchos errores en los datos. Por lo tanto, tenemos que utilizar otra fuente de datos para el algoritmo de trading real
#
# </br>
#
# Importar directamente desde el brocker (Lo veremos en las siguientes parte)
# * AlphaVantage
# * MorningStar
